# %% [markdown]
# # Project Title: NutriCal : McDonald's Menu Nutritional Analysis
#
#    By: Vijay Prakash

# %% [markdown]
# # Contents
#
# (1)Introduction
#
# (2)Problem Statement
#
# (3)Analysing and Understanding Data
#
#     •Analysing Rows and Column
#
#     •Information about data columns and its type
#
#     •Printing of top rows
#
# (4)Handle missing values and data cleaning
#
# (5)Import necessory libraries
#
# (6)Checking duplicate values
#
#     •Checking null values
#
# (7)Exploratory Data Analysis (EDA) And Data Visualization:
#
#     •Analyze the distribution of calorie counts across menu items.
#
#     •Explore the nutritional content (e.g., fat, protein, carbohydrates) of different items.
#
#     •Identify trends and patterns in the dataset.
#
#     •Create bar charts, histograms, and box plots to visualize calorie distribution and nutritional content.
#
#     •Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).
#
# (8)Analyze the distribution of calorie counts across menu items.
#
#     •Explore the Nutrition content (e.g. fat,protein carbohydrates) of different Items.
#
# (9)Nutrition-Based Insights
#
# (10)Documentation and Reporting
#
#     •Summarize the findings and insights from the analysis.
#
#     •Explain how the nutritional analysis could benefit McDonald's customers and the organization.
#
# (11)Recommendations for Improving McDonald's Menu Nutritional Profile
#
# (12)Conclusion

# %% [markdown]
# # Introduction :
#
# In this project we have to extract meaningful information from the McDonalds menu nutritional dataset. and we
#
# have to perform exploratory data analysis to understand the nutritional distribution and trends. using Visualization we have to
#
# present the present calorie count and nutrition facts of different menu items. we have to find healthy and less healthy menu
#
# options.

# %% [markdown]
# # Problem Statement :
#
#  McDonald's is a global fast-food chain known for its diverse menu offerings. As a data analyst, your task
#
#  is to analyze the nutritional content of the menu items available at McDonald's outlets. This analysis will provide valuable
#
#  insights into the calorie count and nutrition facts of various menu items.

# %% [markdown]
# # Downloading the Dataset
# I have downloaded the data provided by my learning platform upgrad
#
# https://knowledgehutglobal-my.sharepoint.com/personal/lsstorage_knowledgehut_com/_layouts/15/onedrive.aspx?id=%2Fpersonal%2Flsstorage%5Fknowledgehut%5Fcom%2FDocuments%2F62%5FData%20Analyst%20Bootcamp%20Capstone%20Projects%2FNutrical%20Dataset&ga=1

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Analysing and Understanding Data

# %%
# importing and assigning dataset

import pandas as pd
df = pd.read_csv("Nutrical Dataset.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#Check for duplicate value
df[df.duplicated()].count().sum()
# Out:
# 0

# %%
#checking the missing values if any exists
print(df.isnull().any())
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %%
#Load and inspect the dataset
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %% [markdown]
# # Handle missing values and data cleaning

# %%
#Handle missing values and data cleaning
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA) And Data Visualization:
#
# (1)Analyze the distribution of calorie counts across menu items.
#
# (2)Explore the nutritional content (e.g., fat, protein, carbohydrates) of different items.
#
# (3)Identify trends and patterns in the dataset.
#
# (4)Create bar charts, histograms, and box plots to visualize calorie distribution and nutritional content.
#
# (5)Compare nutritional characteristics of different food categories (e.g., burgers, salads, desserts).

# %% [markdown]
# # Analyze the distribution of calorie counts across menu items.
#
# Let's begin by importing matplotlib.pyplot, seaborn and numpy

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# I am taking some random items, analysing and visualising their calories counts across menu items

# %%
Item_values = df[['Calories','Total Fat','Carbohydrates','Dietary Fiber','Sugars','Protein',
                 'Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()

print(Item_values)
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# According to the dataset summary
#
# (1)According to dataset, Calories has highest amount of nutrients in the list of food items.
#
# (2)And Dietary Fiber is the lowest present in the list of food items.

# %%
# Explore nutritional content
average_nutrition = df.groupby('Category')[['Sugars','Protein', 'Calories', 'Carbohydrates']].mean()

# %% [markdown]
# # Creating Histogram

# %%
## Identify trends and patterns
# Creating histograms plot for Visualisation

plt.figure(figsize=(12, 8))
sns.histplot(df['Calories'], bins=30, kde=True)
plt.title('Distribution of Calorie Counts')
plt.show()

# %% [markdown]
# •The x-axis represents the range of calorie counts in the dataset.
#
# •The y-axis represents the calorie counts that fall within each bin.
#
# •The KDE line is a smooth curve that follows the histogram. It represents the density of the calorie counts data, with higher   density areas corresponding to more frequent calorie counts.
#
# •In conclusion, this code creates a histogram plot of calorie counts from a dataset. It helps visualize the distribution of calorie counts and identify trends or patterns in the data.

# %% [markdown]
# # Creating bar plot

# %%
# Create a bar chart for calorie distribution 

plt.figure(figsize=(12, 8))
sns.barplot(x='Category', y='Calories',hue='Calories', data=average_nutrition, palette='viridis')
plt.title('Calories Content Across Menu')
plt.xlabel('Menu Categories')
plt.ylabel('Calories (g)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Calories', loc='upper right')  
plt.show()

# %% [markdown]
# (1)We have created a bar chart to visualize the calorie content of various menu categories. The bar chart displays the calorie count for each menu category and also highlights the individual calorie content of each menu item within that category. we used hue to represent the calorie content, allowing us to compare and contrast the nutritional content of different menu items.
#
# (2)From the above bar plot of items, we can see that chicken and Fish has highest amount of Calories
# and beverages has lowest.
#
# (3)Salads has more Calories than Desserts.

# %%
# Box plot for distribution of calorie counts
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Calories',hue='Category', data=df, palette='rainbow')
plt.title('Box Plot of Calorie Counts Across Menu Categories')
plt.xlabel('Menu Categories')
plt.ylabel('Calorie Counts')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# (1)We have created a box plot to visualize the distribution of calorie counts for various menu categories. This box plot provides an overview of the spread of calorie counts for each menu category and also helps to identify any potential outliers.hue is used to distinguish between different menu categories, allowing users to easily compare the calorie distribution across different menu types.
#
# (2)Here we have a box plot we can clearly see that Chicken and fish has highest amount of Calories and salads has more
#  Calories than desserts.
#
# (3)We have plotted Histogram, bar plot and box plot.
#
# (4)All the plot indicates the same thing about the nutrients distribution in the menu categories.

# %%
# Create a bar chart for nutritional content Protein

plt.figure(figsize=(12, 8))
sns.barplot(x='Category', y='Protein',hue='Protein', data=average_nutrition, palette='coolwarm')
plt.title('Protein Content Across Menu')
plt.xlabel('Menu Categories')
plt.ylabel('Protein (g)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Protein', loc='upper right')  
plt.show()

# %% [markdown]
# (1) From the bar chart we can clearly see that in menu categories Chicken and fish has highest protein content.
#
# (2) Beverages has lowest protein content.
#
# (3) Salads has more protein content than desserts.

# %%
# Create a box plot for nutritional content Carbohydrates

plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Carbohydrates',hue='Category', data=df, palette='rainbow')
plt.title('Box Plot of Carbohydrates Counts Across Menu Categories')
plt.xlabel('Menu Categories')
plt.ylabel('Carbohydrates Counts')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Nutrition-Based Insights:
#
# -Identify menu items with the highest and lowest calorie counts.

# %%
calorie_df = df[['Item','Calories','Total Fat']]
calorie_df.min()
# Out:
# Item         1% Low Fat Milk Jug
# Calories                       0
# Total Fat                    0.0
# dtype: object

# %%
calorie_df.max()
# Out:
# Item         Vanilla Shake (Small)
# Calories                      1880
# Total Fat                    118.0
# dtype: object

# %%
Sugar_df = df[['Item','Sugars','Carbohydrates']]
Sugar_df.min()
# Out:
# Item             1% Low Fat Milk Jug
# Sugars                             0
# Carbohydrates                      0
# dtype: object

# %%
Sugar_df.max()
# Out:
# Item             Vanilla Shake (Small)
# Sugars                             128
# Carbohydrates                      141
# dtype: object

# %%
Carbohydrates_df= df[['Item','Carbohydrates','Total Fat']]
Carbohydrates_df.max()
# Out:
# Item             Vanilla Shake (Small)
# Carbohydrates                      141
# Total Fat                        118.0
# dtype: object

# %%
Carbohydrates_df.min()
# Out:
# Item             1% Low Fat Milk Jug
# Carbohydrates                      0
# Total Fat                        0.0
# dtype: object

# %% [markdown]
# # Determine the average nutritional content of popular menu categories.

# %%
# Assuming I have a DataFrame named average_nutrition with columns like 'Category', 'Sugars', 'Calories', 'Carbohydrates'

# Calculate the average nutritional content by menu category
average_nutrition = df.groupby('Category')[['Sugars','Protein', 'Calories', 'Carbohydrates']].mean()


# Display the result
print("Average Nutritional Content by Menu Category:")
print(average_nutrition)
# Out:
# Average Nutritional Content by Menu Category:
#                        Sugars    Protein    Calories  Carbohydrates
# Category
# Beef & Pork          8.800000  27.333333  494.000000      40.133333
# Beverages           27.851852   1.333333  113.703704      28.814815
# Breakfast            8.261905  19.857143  526.666667      49.761905
# Chicken & Fish       7.333333  29.111111  552.962963      49.074074
# Coffee & Tea        39.610526   8.863158  283.894737      44.526316
# Desserts            26.142857   4.000000  222.142857      34.857143
# Salads               6.833333  19.833333  270.000000      21.666667
# Smoothies & Shakes  77.892857  10.857143  531.428571      90.428571
# Snacks & Sides       4.076923   8.384615  245.769231      29.153846

# %% [markdown]
# So I have obtain the average nutritional content of popular categories

# %% [markdown]
# # Documentation and Reporting:
# (1)Summarize the findings and insights from the analysis.
#
# (2)Explain how the nutritional analysis could benefit McDonald's customers and the organization.

# %% [markdown]
# # (1)Summarize the findings and insights from the analysis.

# %% [markdown]
# # (a)Nutritional Values:
#
# I have analyzed the McDonald's menu items for their nutritional content, including calories, fat, carbohydrate, sugar,
#
# protein and sodium.

# %% [markdown]
# # (b)Average Nutritional Content:
#
# We have determined the average nutritional content like sugars, Calories and carbohydrates for each menu category which
#
# provides an overview of the nutritional composition within different menu segments.

# %% [markdown]
# # (c)Distribution of Calorie Counts through histogram:
#
# We have created histogram plot and visualised the calorie distribution counts across all menu items which helps in
#
# understanding the concentration of calorie values within the menu.

# %% [markdown]
# # (d)Calorie Content Across Menu:
#
# (1) We have created bar chart to compare the calorie content across different menu categories.
#
# (2) This allows for a quick assessment of the calorie variations among menu items.
#
# (3) From the bar chart we clearly see that Chicken and fish has highest amount of Calories and beverages has lowest.

# %% [markdown]
# # (e)Box Plot of Calorie Counts:
#
# A box plot shows how calorie counts vary across different menu categories, highlighting potential outliers.

# %% [markdown]
# # (2)Explain how the nutritional analysis could benefit McDonald's customers & the organization.

# %% [markdown]
# # Benefits for McDonald's Customers:

# %% [markdown]
# # (a)Informed Decision-Making:
#
# (1) Customers can make a decision based on the maximum nutritional values, average content,
#
#    and distribution patterns.
#
# (2) This prevails them to choose their meal as per dietary preferences
#
#    or specific nutritional requirements.

# %% [markdown]
# # (b)Visual Understanding:
#
# (1) Visualizations like histograms, bar charts, and box plots offer an intuitive understanding of nutritional data.
#
# (2) Customers can quickly grasp trends, distribution, and comparative information, aiding in efficient decision-making.

# %% [markdown]
# # Benefits for McDonald's Organization:

# %% [markdown]
# # (a)Analyzing McDonald's Menu: A Recipe for Improvement
#
# • Understanding the average nutritional content of its menu categories gives McDonald's a powerful tool
#
#   to make its offerings more appealing and potentially healthier.

# %% [markdown]
# # (b)Marketing and Transparency:
#
# • Utilizing visualizations in marketing materials can enhance transparency and communication. Promoting healthier
#
#  options and showcasing nutritional trends can positively impact the brand's image, attracting health-conscious consumers.

# %% [markdown]
# # (c)Quality Assurance:
#
# (1) Monitoring maximum nutritional values and distribution patterns allows McDonald's to ensure quality control.
#
# (2) Identifying outliers or inconsistencies in nutritional content facilitates adherence to quality standards and
#
#     regulatory requirements.

# %% [markdown]
# # Recommendations for Improving McDonald's Menu Nutritional Profile:

# %% [markdown]
# # (a)Introducing Healthier Ingredients at McDonald's:
#
# (1) Incorporate more whole grains, lean proteins, and fresh produce into menu items.
#
# (2) Offer alternative protein sources such as plant-based options to cater to diverse dietary preferences.

# %% [markdown]
# # (b)Reduced Sodium Content:
#
# (1) Implement strategies to reduce the overall sodium content in menu items, such as using herbs and spices for
#
#   flavoring instead of salt.
#
# (2) Offer low-sodium alternatives for customers who are conscious of their sodium intake.

# %% [markdown]
# # (c)Promote Customization:
#
# (1) Allow customers to customize their orders easily, enabling them to choose healthier options or modify ingredients
#
#  based on their preferences.
#
# (2) Implement a "build your own" option for certain menu items.

# %% [markdown]
# # (d)Increase Transparency:
#
# • Provide information about allergies to assist customers with dietary restrictions or allergies.

# %% [markdown]
# # (e)Regular Menu Evaluation and Updates:
#
# (1) Periodically review and update the menu based on nutritional trends, customer feedback, and emerging health guidelines.
#
# (2) Stay adaptable to changing consumer preferences and health-conscious trends.

# %% [markdown]
# # (f)Collaborate with Nutrition Experts:
#
# (1) Partner with nutritionists or health experts to assess and enhance the nutritional profile of menu items.
#
# (2) Seek guidance on ingredient choices, cooking methods, and overall menu planning.

# %% [markdown]
# # (g)Customer Feedback Mechanism:
#
# (1) Establish a system for collecting customer feedback on nutritional aspects and preferences.
#
# (2) Use this feedback to refine menu offerings and address specific customer needs.

# %% [markdown]
# # Conclusion:
#
# (1) In conclusion, the nutritional analysis provides valuable insights for both McDonald's customers and the organization.
#
# (2) Customers gain the ability to make informed choices, while McDonald's can leverage the findings for menu customization,
#
#    Marketing, and quality assurance, contributes to a more health-conscious and customer-centric approach.
